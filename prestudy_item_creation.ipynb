# %% [markdown]
# Goal is to create 150 tuples that contain nouns with the same animacy (similar group) and 150 tuples that contain nouns with different animacy (contrast group), to calculate their similarity values and to export the created dataframe for data analysis later on.

# %%
import csv
import pandas as pd
from gensim.models.word2vec import Text8Corpus
from gensim.models import Word2Vec

# %% [markdown]
# First of all, a csv file which contains animate and inanimate nouns is uploaded. The nouns stem from the brown corpus. By using nltk all nouns were extracted out of the brown corpus and randomized. After that, the first 150 animate and inanimte nouns were extracted. Pseudowords, Names, words that were not clearly assignable to the animate or inanimate category or words that were not contained in the training dataset of the word2vec model were excluded.
#
# The path represents the place where the csv file is stored.
# This csv file is accessed and opend for reading purposes.
# All items are stored in one line and separated by ';'. The file, only containing line 0, has to be splitted in many parts after each ';', such that the items are accessible.
# All animate and inanimate nouns are extracted and stored in their correspinding lists.

# %%
file=open("Nouns_prestudy.CSV", "r")

noun_file = csv.reader(file)

animate=[]
inanimate=[]
for line in noun_file:
    splitted_file=line[0].split(sep=";")
    animate.append(splitted_file[0])
    inanimate.append(splitted_file[1])
print(animate, inanimate)
# Out:
# ['Animate', 'guard', 'peoples', 'uncle', 'men', 'workers', 'fish', 'teacher', 'battalion', 'liberal', 'commentators', 'attorney', 'founders', 'beef', 'partner', 'principal', 'victim', 'girls', 'communists', 'coach', 'president', 'governance', 'peasant', 'daughters', 'employee', 'lady', 'master', 'commanders', 'delegates', 'tourists', 'mother', 'parent', 'commissioner', 'bird', 'dolphin', 'viewers', 'editor', 'individual', 'sons', 'scholars', 'chancellor', 'prisoners', 'wife', 'couple', 'lover', 'musicians', 'veterans', 'elite', 'couple', 'commanders', 'dealer', 'swan', 'researcher', 'bully', 'tiger', 'confessor', 'grandmother', 'shopkeeper', 'neighbor', 'militarist', 'supervisor', 'fishermen', 'lifeguard', 'catcher', 'maid', 'dispenser', 'sociologist', 'banker', 'piers', 'landlord', 'sinner', 'boss', 'proprietor', 'council', 'postmaster', 'sister', 'committee', 'eyewitness', 'developer', 'referent', 'boa', 'junior', 'amateur', 'misses', 'husband', 'shipmates', 'senator', 'pilot', 'pickers', 'buyer', 'liberals', 'astronomer', 'intellectuals', 'grandfathers', 'merchants', 'salesman', 'referee', 'stewardess', 'intruders', 'alcoholics', 'missionary', 'nurse', 'cobbler', 'builder', 'politician', 'racist', 'reporter', 'student', 'employers', 'celebrity', 'owner', 'humorist', 'liar', 'nationals', 'millionaire', 'bishop', 'mayor', 'artist', 'princess', 'householder', 'gymnast', 'customer', 'pianist', 'retailers', 'assassins', 'giant', 'planner', 'female', 'thinker', 'controller', 'civilian', 'craftsman', 'travellers', 'poets', 'analyst', 'sardines', 'preacher', 'youths', 'planters', 'purist', 'spectators', 'instructor', 'champions', 'police', 'selectors', 'graduate', 'contender', 'farmer', 'descendant', 'dancers', 'horse'] ['Inanimate', 'suffrage', 'incest', 'sea', 'demonstrations', 'definition', 'experiment', 'cosmology', 'canon', 'portrait', 'listing', 'protest', 'suburb', 'timber', 'studio', 'status', 'compensation', 'chronicle', 'convention', 'formation', 'doctrine', 'policies', 'boat', 'vectors', 'moment', 'discrimination', 'factors', 'panel', 'materials', 'management', 'switches', 'money', 'records', 'coal', 'needs', 'developments', 'opinion', 'names', 'hotel', 'octave', 'security', 'thesis', 'head', 'stick', 'groups', 'chambers', 'technique', 'boards', 'privacy', 'corruption', 'faith', 'pans', 'imperative', 'specimen', 'tracer', 'suffrage', 'arteries', 'engraving', 'canyon', 'wakefulness', 'logarithm', 'outrages', 'social', 'class', 'coal', 'contentment', 'malady', 'menu', 'charity', 'meantime', 'club', 'appointment', 'moral', 'siren', 'radius', 'lips', 'equal', 'helicopter', 'death', 'lemon', 'ice', 'application', 'result', 'findings', 'correlation', 'orchestra', 'denial', 'existence', 'heaven', 'agreement', 'collaboration', 'country', 'jacket', 'defeats', 'greetings', 'limit', 'illustration', 'sequence', 'hospitality', 'criterion', 'republic', 'hope', 'phonology', 'lingerie', 'concept', 'game', 'bar', 'press', 'city', 'cigarette', 'tradition', 'risk', 'building', 'handwriting', 'economy', 'lounge', 'doubts', 'benefits', 'margins', 'music', 'cartoon', 'night', 'cake', 'month', 'income', 'winter', 'foot', 'airplane', 'niche', 'taint', 'essays', 'town', 'nuclei', 'access', 'honour', 'membrane', 'dust', 'milligrams', 'fashion', 'explorations', 'quality', 'beginning', 'departure', 'tape', 'cerebellum', 'cooperative', 'plane', 'ear', 'finality', 'quote', 'arcades']

# %% [markdown]
# Since the first item of our two lists are the headings, we delete them. We don't want to have the headings in the tuples later on.

# %%
animate.pop(0)
inanimate.pop(0)
# Out:
# 'Inanimate'

# %% [markdown]
# We create our first data frame df which only contains our animate and inanimate items.

# %%
df = pd.DataFrame(list(zip(animate, inanimate)),
                          columns =['Animate', 'Inanimate'])
df
# Out:
#         Animate       Inanimate
# 0         guard        suffrage
# 1       peoples          incest
# 2         uncle             sea
# 3           men  demonstrations
# 4       workers      definition
# ..          ...             ...
# 145   contender           plane
# 146      farmer             ear
# 147  descendant        finality
# 148     dancers           quote
# 149       horse         arcades
#
# [150 rows x 2 columns]

# %% [markdown]
# We now want to check whether all nouns are in the training dataset. With missing nouns no similarity values can be calculated.
# To do so, we need to upload our word2vec model. We take the pre trained word vectors that have been trained on the text8 corpus. For the pre study we take the same min_count as in our main experiment later (min_count=5).

# %%
w2v_model = Word2Vec(
    Text8Corpus(r'C:\\Users\\marie\\Dropbox\\Uni_Potsdam\\Vasishth\\Thesis\\Word2Vec\\text8'),
    size=100,
    window=5,
    min_count=5,#we need 5 here
    workers=3)

# %% [markdown]
# To check whether all words of our two lists are contained in the training dataset we add two new columns to our dataframe that containes the boolien expression TRUE when a word is contained in the dataset and FALSE when it is not contained.
# We use the lambda function to check each row of the animate list and apply the result to the new column 'animate_inW2v'. We do the same for the contrast list. To be able to see the whole output we specify that we want to see all 150 rows in the output window.

# %%
#Check whether all words are in the training dataset
word_dict = w2v_model.wv.vocab
df['animate_inW2v'] = df.Animate.apply(lambda x: x in word_dict)
df['inanimate_inW2V'] = df.Inanimate.apply(lambda x: x in word_dict)
pd.set_option('display.max_rows', 150)
df
# Out:
#            Animate       Inanimate  animate_inW2v  inanimate_inW2V
# 0            guard        suffrage           True             True
# 1          peoples          incest           True             True
# 2            uncle             sea           True             True
# 3              men  demonstrations           True             True
# 4          workers      definition           True             True
# 5             fish      experiment           True             True
# 6          teacher       cosmology           True             True
# 7        battalion           canon           True             True
# 8          liberal        portrait           True             True
# 9     commentators         listing           True             True
# 10        attorney         protest           True             True
# 11        founders          suburb           True             True
# 12            beef          timber           True             True
# 13         partner          studio           True             True
# 14       principal          status           True             True
# 15          victim    compensation           True             True
# 16           girls       chronicle           True             True
# 17      communists      convention           True             True
# 18           coach       formation           True             True
# 19       president        doctrine           True             True
# 20      governance        policies           True             True
# 21         peasant            boat           True             True
# 22       daughters         vectors           True             True
# 23        employee          moment           True             True
# 24            lady  discrimination           True             True
# 25          master         factors           True             True
# 26      commanders           panel           True             True
# 27       delegates       materials           True             True
# 28        tourists      management           True             True
# 29          mother        switches           True             True
# 30          parent           money           True             True
# 31    commissioner         records           True             True
# 32            bird            coal           True             True
# 33         dolphin           needs           True             True
# 34         viewers    developments           True             True
# 35          editor         opinion           True             True
# 36      individual           names           True             True
# 37            sons           hotel           True             True
# 38        scholars          octave           True             True
# 39      chancellor        security           True             True
# 40       prisoners          thesis           True             True
# 41            wife            head           True             True
# 42          couple           stick           True             True
# 43           lover          groups           True             True
# 44       musicians        chambers           True             True
# 45        veterans       technique           True             True
# 46           elite          boards           True             True
# 47          couple         privacy           True             True
# 48      commanders      corruption           True             True
# 49          dealer           faith           True             True
# 50            swan            pans           True             True
# 51      researcher      imperative           True             True
# 52           bully        specimen           True             True
# 53           tiger          tracer           True             True
# 54       confessor        suffrage           True             True
# 55     grandmother        arteries           True             True
# 56      shopkeeper       engraving           True             True
# 57        neighbor          canyon           True             True
# 58      militarist     wakefulness           True             True
# 59      supervisor       logarithm           True             True
# 60       fishermen        outrages           True             True
# 61       lifeguard          social           True             True
# 62         catcher           class           True             True
# 63            maid            coal           True             True
# 64       dispenser     contentment           True             True
# 65     sociologist          malady           True             True
# 66          banker            menu           True             True
# 67           piers         charity           True             True
# 68        landlord        meantime           True             True
# 69          sinner            club           True             True
# 70            boss     appointment           True             True
# 71      proprietor           moral           True             True
# 72         council           siren           True             True
# 73      postmaster          radius           True             True
# 74          sister            lips           True             True
# 75       committee           equal           True             True
# 76      eyewitness      helicopter           True             True
# 77       developer           death           True             True
# 78        referent           lemon           True             True
# 79             boa             ice           True             True
# 80          junior     application           True             True
# 81         amateur          result           True             True
# 82          misses        findings           True             True
# 83         husband     correlation           True             True
# 84       shipmates       orchestra           True             True
# 85         senator          denial           True             True
# 86           pilot       existence           True             True
# 87         pickers          heaven           True             True
# 88           buyer       agreement           True             True
# 89        liberals   collaboration           True             True
# 90      astronomer         country           True             True
# 91   intellectuals          jacket           True             True
# 92    grandfathers         defeats           True             True
# 93       merchants       greetings           True             True
# 94        salesman           limit           True             True
# 95         referee    illustration           True             True
# 96      stewardess        sequence           True             True
# 97       intruders     hospitality           True             True
# 98      alcoholics       criterion           True             True
# 99      missionary        republic           True             True
# 100          nurse            hope           True             True
# 101        cobbler       phonology           True             True
# 102        builder        lingerie           True             True
# 103     politician         concept           True             True
# 104         racist            game           True             True
# 105       reporter             bar           True             True
# 106        student           press           True             True
# 107      employers            city           True             True
# 108      celebrity       cigarette           True             True
# 109          owner       tradition           True             True
# 110       humorist            risk           True             True
# 111           liar        building           True             True
# 112      nationals     handwriting           True             True
# 113    millionaire         economy           True             True
# 114         bishop          lounge           True             True
# 115          mayor          doubts           True             True
# 116         artist        benefits           True             True
# 117       princess         margins           True             True
# 118    householder           music           True             True
# 119        gymnast         cartoon           True             True
# 120       customer           night           True             True
# 121        pianist            cake           True             True
# 122      retailers           month           True             True
# 123      assassins          income           True             True
# 124          giant          winter           True             True
# 125        planner            foot           True             True
# 126         female        airplane           True             True
# 127        thinker           niche           True             True
# 128     controller           taint           True             True
# 129       civilian          essays           True             True
# 130      craftsman            town           True             True
# 131     travellers          nuclei           True             True
# 132          poets          access           True             True
# 133        analyst          honour           True             True
# 134       sardines        membrane           True             True
# 135       preacher            dust           True             True
# 136         youths      milligrams           True             True
# 137       planters         fashion           True             True
# 138         purist    explorations           True             True
# 139     spectators         quality           True             True
# 140     instructor       beginning           True             True
# 141      champions       departure           True             True
# 142         police            tape           True             True
# 143      selectors      cerebellum           True             True
# 144       graduate     cooperative           True             True
# 145      contender           plane           True             True
# 146         farmer             ear           True             True
# 147     descendant        finality           True             True
# 148        dancers           quote           True             True
# 149          horse         arcades           True             True

# %% [markdown]
# We can see that indeed every word is contained in the training dataset which means that we can continue...

# %% [markdown]
# The next goal is to create a dataframe that containes tuples (pairs of nouns). One column should contain tuples with nouns with the same animacy (similar_tuples) and one column should contain tuples with nouns with different animacy (contrast_tuples).

# %% [markdown]
# To create those tuples we start by extracting the 'Animate' and 'Inanimate' column out of our dataframe df and create two separate lists, containing the corresponding items.

# %%
Animate = list(df['Animate'])
Inanimate = list(df['Inanimate'])

# %% [markdown]
# For the similar group, we always want to pair the two items that stand one below the other within each group. Therefore we create one list containing each second entry of the animate and inanimate list (one starts at 0, the other at 1). We merge the corresponding similar and contrast parts together (a to a and b to b)

# %%
# create the similar group: always pair the two items that are one below the other (just within the groups)

similar_list_Animate_a = Animate[0::2]
similar_list_Animate_b = Animate[1::2]
similar_list_Inanimate_a = Inanimate[0::2]
similar_list_Inanimate_b = Inanimate[1::2]

similar_list_a = similar_list_Animate_a+similar_list_Inanimate_a
similar_list_b = similar_list_Animate_b+similar_list_Inanimate_b

# %% [markdown]
# Now that we have the two lists that we need to create our similar tuples, we store them in a new dataframe called df_similar.
# Next, we want to calculate the similarity between the two words that are in each row (word x of list a with word x of list b).
# To do so, we assign the similarity function to the variable sim. We then use again the lambda function to apply the similarity function for each row of the dataframe and store the results in a new column called 'simval_similar'

# %%
#Create a pandas dataframe for the similar dataset
df_similar = pd.DataFrame(list(zip(similar_list_a, similar_list_b)),
                          columns =['similar_list_a', 'similar_list_b'])
sim = w2v_model.wv.similarity 
df_similar['simval_similar'] = df_similar.apply(lambda row: sim(row.similar_list_a, row.similar_list_b), axis=1)
df_similar
# Out:
#      similar_list_a  similar_list_b  simval_similar
# 0             guard         peoples        0.072658
# 1             uncle             men        0.199144
# 2           workers            fish        0.185286
# 3           teacher       battalion        0.016067
# 4           liberal    commentators        0.369242
# 5          attorney        founders        0.305781
# 6              beef         partner        0.116828
# 7         principal          victim       -0.119173
# 8             girls      communists        0.003628
# 9             coach       president        0.456646
# 10       governance         peasant        0.237982
# 11        daughters        employee        0.090469
# 12             lady          master        0.354616
# 13       commanders       delegates        0.276163
# 14         tourists          mother        0.087224
# 15           parent    commissioner        0.099814
# 16             bird         dolphin        0.659919
# 17          viewers          editor        0.175560
# 18       individual            sons        0.026401
# 19         scholars      chancellor        0.066708
# 20        prisoners            wife        0.150696
# 21           couple           lover        0.435434
# 22        musicians        veterans        0.241846
# 23            elite          couple        0.049244
# 24       commanders          dealer        0.082946
# 25             swan      researcher        0.167915
# 26            bully           tiger        0.316549
# 27        confessor     grandmother        0.536951
# 28       shopkeeper        neighbor        0.329234
# 29       militarist      supervisor        0.235407
# 30        fishermen       lifeguard        0.373334
# 31          catcher            maid        0.561845
# 32        dispenser     sociologist        0.089350
# 33           banker           piers        0.317004
# 34         landlord          sinner        0.444995
# 35             boss      proprietor        0.551833
# 36          council      postmaster        0.289098
# 37           sister       committee       -0.103927
# 38       eyewitness       developer        0.095075
# 39         referent             boa        0.374025
# 40           junior         amateur        0.368408
# 41           misses         husband        0.220981
# 42        shipmates         senator        0.138344
# 43            pilot         pickers        0.223750
# 44            buyer        liberals        0.268742
# 45       astronomer   intellectuals        0.245128
# 46     grandfathers       merchants        0.219265
# 47         salesman         referee        0.164490
# 48       stewardess       intruders        0.708323
# 49       alcoholics      missionary        0.191690
# 50            nurse         cobbler        0.438142
# 51          builder      politician        0.411202
# 52           racist        reporter        0.223373
# 53          student       employers        0.340352
# 54        celebrity           owner        0.380071
# 55         humorist            liar        0.384497
# 56        nationals     millionaire        0.201383
# 57           bishop           mayor        0.546403
# 58           artist        princess        0.354159
# 59      householder         gymnast        0.346676
# 60         customer         pianist       -0.267622
# 61        retailers       assassins        0.225525
# 62            giant         planner        0.117533
# 63           female         thinker        0.027385
# 64       controller        civilian       -0.032221
# 65        craftsman      travellers        0.165084
# 66            poets         analyst        0.153222
# 67         sardines        preacher        0.173873
# 68           youths        planters        0.398463
# 69           purist      spectators        0.061744
# 70       instructor       champions        0.040920
# 71           police       selectors        0.235224
# 72         graduate       contender        0.169244
# 73           farmer      descendant        0.481392
# 74          dancers           horse        0.468846
# 75         suffrage          incest        0.280723
# 76              sea  demonstrations       -0.095054
# 77       definition      experiment        0.182097
# 78        cosmology           canon        0.401291
# 79         portrait         listing        0.107994
# 80          protest          suburb        0.108032
# 81           timber          studio       -0.005239
# 82           status    compensation        0.426271
# 83        chronicle      convention        0.110268
# 84        formation        doctrine        0.159094
# 85         policies            boat       -0.204082
# 86          vectors          moment        0.144807
# 87   discrimination         factors        0.352982
# 88            panel       materials        0.085945
# 89       management        switches        0.256898
# 90            money         records        0.177110
# 91             coal           needs        0.038485
# 92     developments         opinion        0.319240
# 93            names           hotel       -0.039449
# 94           octave        security       -0.207031
# 95           thesis            head        0.009819
# 96            stick          groups       -0.017609
# 97         chambers       technique       -0.053550
# 98           boards         privacy        0.373797
# 99       corruption           faith        0.251447
# 100            pans      imperative        0.125150
# 101        specimen          tracer        0.274875
# 102        suffrage        arteries       -0.127570
# 103       engraving          canyon        0.243519
# 104     wakefulness       logarithm        0.200884
# 105        outrages          social        0.066802
# 106           class            coal        0.038373
# 107     contentment          malady        0.418817
# 108            menu         charity        0.017543
# 109        meantime            club        0.221057
# 110     appointment           moral        0.254113
# 111           siren          radius        0.310828
# 112            lips           equal        0.080291
# 113      helicopter           death       -0.068966
# 114           lemon             ice        0.320127
# 115     application          result        0.166517
# 116        findings     correlation        0.277745
# 117       orchestra          denial       -0.339395
# 118       existence          heaven        0.392595
# 119       agreement   collaboration        0.315872
# 120         country          jacket       -0.094284
# 121         defeats       greetings        0.005609
# 122           limit    illustration        0.154180
# 123        sequence     hospitality       -0.127187
# 124       criterion        republic        0.062358
# 125            hope       phonology       -0.147273
# 126        lingerie         concept       -0.183202
# 127            game             bar        0.163190
# 128           press            city        0.054807
# 129       cigarette       tradition       -0.115003
# 130            risk        building       -0.086207
# 131     handwriting         economy       -0.003597
# 132          lounge          doubts       -0.103825
# 133        benefits         margins        0.196101
# 134           music         cartoon        0.253553
# 135           night            cake        0.297786
# 136           month          income        0.243430
# 137          winter            foot        0.210078
# 138        airplane           niche        0.193664
# 139           taint          essays        0.114440
# 140            town          nuclei       -0.102117
# 141          access          honour       -0.094404
# 142        membrane            dust        0.601756
# 143      milligrams         fashion       -0.145451
# 144    explorations         quality        0.111974
# 145       beginning       departure        0.375800
# 146            tape      cerebellum        0.240027
# 147     cooperative           plane       -0.063369
# 148             ear        finality        0.176993
# 149           quote         arcades        0.011649

# %% [markdown]
# We do the same for the contrast tuples.

# %%
# create the contrast group: always pair the two items that are in the same row (animate with inanimate)

df_contrast = pd.DataFrame(list(zip(Animate, Inanimate)),
                          columns =['Animate', 'Inanimate'])
df_contrast['simval_contrast'] = df_contrast.apply(lambda row: sim(row.Animate, row.Inanimate), axis=1)
df_contrast
# Out:
#            Animate       Inanimate  simval_contrast
# 0            guard        suffrage         0.007539
# 1          peoples          incest         0.081350
# 2            uncle             sea        -0.005888
# 3              men  demonstrations         0.152362
# 4          workers      definition        -0.126815
# 5             fish      experiment        -0.135816
# 6          teacher       cosmology         0.136031
# 7        battalion           canon        -0.072913
# 8          liberal        portrait         0.030814
# 9     commentators         listing        -0.044760
# 10        attorney         protest         0.254799
# 11        founders          suburb         0.363557
# 12            beef          timber         0.657578
# 13         partner          studio         0.282995
# 14       principal          status         0.014060
# 15          victim    compensation         0.244506
# 16           girls       chronicle         0.128781
# 17      communists      convention         0.179345
# 18           coach       formation        -0.081156
# 19       president        doctrine         0.157285
# 20      governance        policies         0.606047
# 21         peasant            boat         0.120473
# 22       daughters         vectors        -0.034526
# 23        employee          moment         0.050138
# 24            lady  discrimination        -0.051865
# 25          master         factors        -0.205206
# 26      commanders           panel         0.006112
# 27       delegates       materials        -0.120178
# 28        tourists      management         0.049451
# 29          mother        switches        -0.240633
# 30          parent           money         0.288705
# 31    commissioner         records         0.054857
# 32            bird            coal         0.224455
# 33         dolphin           needs        -0.225833
# 34         viewers    developments         0.138406
# 35          editor         opinion         0.196598
# 36      individual           names         0.056916
# 37            sons           hotel         0.034581
# 38        scholars          octave        -0.036662
# 39      chancellor        security         0.267201
# 40       prisoners          thesis        -0.087898
# 41            wife            head         0.229502
# 42          couple           stick         0.190971
# 43           lover          groups        -0.207774
# 44       musicians        chambers        -0.083194
# 45        veterans       technique        -0.203489
# 46           elite          boards         0.201985
# 47          couple         privacy        -0.099502
# 48      commanders      corruption         0.204247
# 49          dealer           faith        -0.058113
# 50            swan            pans         0.481573
# 51      researcher      imperative         0.124441
# 52           bully        specimen         0.164963
# 53           tiger          tracer         0.272061
# 54       confessor        suffrage         0.124433
# 55     grandmother        arteries         0.129290
# 56      shopkeeper       engraving         0.275371
# 57        neighbor          canyon         0.171279
# 58      militarist     wakefulness         0.276992
# 59      supervisor       logarithm         0.052898
# 60       fishermen        outrages         0.365466
# 61       lifeguard          social        -0.083376
# 62         catcher           class         0.008038
# 63            maid            coal        -0.093933
# 64       dispenser     contentment         0.481098
# 65     sociologist          malady         0.412845
# 66          banker            menu        -0.122099
# 67           piers         charity         0.082744
# 68        landlord        meantime         0.367191
# 69          sinner            club        -0.170966
# 70            boss     appointment         0.235996
# 71      proprietor           moral        -0.113751
# 72         council           siren         0.044220
# 73      postmaster          radius         0.017442
# 74          sister            lips         0.224995
# 75       committee           equal         0.000378
# 76      eyewitness      helicopter        -0.004600
# 77       developer           death        -0.197566
# 78        referent           lemon         0.190238
# 79             boa             ice         0.257461
# 80          junior     application        -0.178164
# 81         amateur          result        -0.040422
# 82          misses        findings        -0.125160
# 83         husband     correlation         0.026893
# 84       shipmates       orchestra         0.085623
# 85         senator          denial         0.030532
# 86           pilot       existence        -0.080668
# 87         pickers          heaven         0.254389
# 88           buyer       agreement         0.238901
# 89        liberals   collaboration         0.126358
# 90      astronomer         country        -0.218060
# 91   intellectuals          jacket        -0.138436
# 92    grandfathers         defeats         0.297841
# 93       merchants       greetings         0.178035
# 94        salesman           limit        -0.120865
# 95         referee    illustration         0.040986
# 96      stewardess        sequence         0.056528
# 97       intruders     hospitality         0.437522
# 98      alcoholics       criterion         0.174741
# 99      missionary        republic         0.088802
# 100          nurse            hope         0.211268
# 101        cobbler       phonology         0.201073
# 102        builder        lingerie         0.361243
# 103     politician         concept        -0.142412
# 104         racist            game        -0.078894
# 105       reporter             bar         0.130717
# 106        student           press         0.188963
# 107      employers            city         0.197684
# 108      celebrity       cigarette         0.229554
# 109          owner       tradition        -0.097376
# 110       humorist            risk         0.005485
# 111           liar        building        -0.287226
# 112      nationals     handwriting        -0.113511
# 113    millionaire         economy        -0.078690
# 114         bishop          lounge        -0.174905
# 115          mayor          doubts         0.037650
# 116         artist        benefits        -0.163715
# 117       princess         margins        -0.167289
# 118    householder           music         0.106272
# 119        gymnast         cartoon         0.223424
# 120       customer           night         0.030769
# 121        pianist            cake         0.337783
# 122      retailers           month        -0.042924
# 123      assassins          income        -0.178410
# 124          giant          winter         0.068162
# 125        planner            foot        -0.089221
# 126         female        airplane         0.018070
# 127        thinker           niche         0.047057
# 128     controller           taint         0.138501
# 129       civilian          essays        -0.268967
# 130      craftsman            town         0.131550
# 131     travellers          nuclei         0.054858
# 132          poets          access        -0.235397
# 133        analyst          honour         0.159458
# 134       sardines        membrane         0.101320
# 135       preacher            dust        -0.152461
# 136         youths      milligrams         0.149112
# 137       planters         fashion         0.109909
# 138         purist    explorations         0.138597
# 139     spectators         quality         0.208773
# 140     instructor       beginning         0.084929
# 141      champions       departure         0.063059
# 142         police            tape         0.035531
# 143      selectors      cerebellum         0.260630
# 144       graduate     cooperative         0.379130
# 145      contender           plane         0.049236
# 146         farmer             ear         0.191714
# 147     descendant        finality         0.283874
# 148        dancers           quote         0.010214
# 149          horse         arcades         0.184137

# %% [markdown]
# For the data analysis we do not want the words that belong to one tuple in seperated columns, but we want one column containing all tuples. Therefore, we extract for each row the corresponding item of list a and list b and store both words in a tuple formate (word_a,word_b) in the similar_tuples and contrast_tuples list.

# %%
similar_tuples=[(similar_list_a[i],similar_list_b[i]) for i in range(0,len(similar_list_a))
contrast_tuples=[(Animate[i],Inanimate[i]) for i in range(0,len(Animate))]

# %% [markdown]
# Now we want to create the final data frame. It should contain one columns with the similar tuples, then a column containing the corresponding similarity values, after that a column with the contrast tuples and again the corresponding similarity values.
#
# To do so, we extract the already calculated similarity values out of the similar and the contrast dataframe and create the new dataframe calles df_simval with all needed columns.

# %%
simval_similar = list(df_similar['simval_similar'])
simval_contrast = list(df_contrast['simval_contrast'])
df_simval = pd.DataFrame(list(zip(similar_tuples, simval_similar, contrast_tuples, simval_contrast)),
                          columns =['Similar_tuples', 'Simval_similar', 'Contrast_tuples', 'Simval_contrast'])
df_simval
# Out:
#                   Similar_tuples  Simval_similar            Contrast_tuples  \
# 0               (guard, peoples)        0.072658          (guard, suffrage)
# 1                   (uncle, men)        0.199144          (peoples, incest)
# 2                (workers, fish)        0.185286               (uncle, sea)
# 3           (teacher, battalion)        0.016067      (men, demonstrations)
# 4        (liberal, commentators)        0.369242      (workers, definition)
# 5           (attorney, founders)        0.305781         (fish, experiment)
# 6                (beef, partner)        0.116828       (teacher, cosmology)
# 7            (principal, victim)       -0.119173         (battalion, canon)
# 8            (girls, communists)        0.003628        (liberal, portrait)
# 9             (coach, president)        0.456646    (commentators, listing)
# 10         (governance, peasant)        0.237982        (attorney, protest)
# 11         (daughters, employee)        0.090469         (founders, suburb)
# 12                (lady, master)        0.354616             (beef, timber)
# 13       (commanders, delegates)        0.276163          (partner, studio)
# 14            (tourists, mother)        0.087224        (principal, status)
# 15        (parent, commissioner)        0.099814     (victim, compensation)
# 16               (bird, dolphin)        0.659919         (girls, chronicle)
# 17             (viewers, editor)        0.175560   (communists, convention)
# 18            (individual, sons)        0.026401         (coach, formation)
# 19        (scholars, chancellor)        0.066708      (president, doctrine)
# 20             (prisoners, wife)        0.150696     (governance, policies)
# 21               (couple, lover)        0.435434            (peasant, boat)
# 22         (musicians, veterans)        0.241846       (daughters, vectors)
# 23               (elite, couple)        0.049244         (employee, moment)
# 24          (commanders, dealer)        0.082946     (lady, discrimination)
# 25            (swan, researcher)        0.167915          (master, factors)
# 26                (bully, tiger)        0.316549        (commanders, panel)
# 27      (confessor, grandmother)        0.536951     (delegates, materials)
# 28        (shopkeeper, neighbor)        0.329234     (tourists, management)
# 29      (militarist, supervisor)        0.235407         (mother, switches)
# 30        (fishermen, lifeguard)        0.373334            (parent, money)
# 31               (catcher, maid)        0.561845    (commissioner, records)
# 32      (dispenser, sociologist)        0.089350               (bird, coal)
# 33               (banker, piers)        0.317004           (dolphin, needs)
# 34            (landlord, sinner)        0.444995    (viewers, developments)
# 35            (boss, proprietor)        0.551833          (editor, opinion)
# 36         (council, postmaster)        0.289098        (individual, names)
# 37           (sister, committee)       -0.103927              (sons, hotel)
# 38       (eyewitness, developer)        0.095075         (scholars, octave)
# 39               (referent, boa)        0.374025     (chancellor, security)
# 40             (junior, amateur)        0.368408        (prisoners, thesis)
# 41             (misses, husband)        0.220981               (wife, head)
# 42          (shipmates, senator)        0.138344            (couple, stick)
# 43              (pilot, pickers)        0.223750            (lover, groups)
# 44             (buyer, liberals)        0.268742      (musicians, chambers)
# 45   (astronomer, intellectuals)        0.245128      (veterans, technique)
# 46     (grandfathers, merchants)        0.219265            (elite, boards)
# 47           (salesman, referee)        0.164490          (couple, privacy)
# 48       (stewardess, intruders)        0.708323   (commanders, corruption)
# 49      (alcoholics, missionary)        0.191690            (dealer, faith)
# 50              (nurse, cobbler)        0.438142               (swan, pans)
# 51         (builder, politician)        0.411202   (researcher, imperative)
# 52            (racist, reporter)        0.223373          (bully, specimen)
# 53          (student, employers)        0.340352            (tiger, tracer)
# 54            (celebrity, owner)        0.380071      (confessor, suffrage)
# 55              (humorist, liar)        0.384497    (grandmother, arteries)
# 56      (nationals, millionaire)        0.201383    (shopkeeper, engraving)
# 57               (bishop, mayor)        0.546403         (neighbor, canyon)
# 58            (artist, princess)        0.354159  (militarist, wakefulness)
# 59        (householder, gymnast)        0.346676    (supervisor, logarithm)
# 60           (customer, pianist)       -0.267622      (fishermen, outrages)
# 61        (retailers, assassins)        0.225525        (lifeguard, social)
# 62              (giant, planner)        0.117533           (catcher, class)
# 63             (female, thinker)        0.027385               (maid, coal)
# 64        (controller, civilian)       -0.032221   (dispenser, contentment)
# 65       (craftsman, travellers)        0.165084      (sociologist, malady)
# 66              (poets, analyst)        0.153222             (banker, menu)
# 67          (sardines, preacher)        0.173873           (piers, charity)
# 68            (youths, planters)        0.398463       (landlord, meantime)
# 69          (purist, spectators)        0.061744             (sinner, club)
# 70       (instructor, champions)        0.040920        (boss, appointment)
# 71           (police, selectors)        0.235224        (proprietor, moral)
# 72         (graduate, contender)        0.169244           (council, siren)
# 73          (farmer, descendant)        0.481392       (postmaster, radius)
# 74              (dancers, horse)        0.468846             (sister, lips)
# 75            (suffrage, incest)        0.280723         (committee, equal)
# 76         (sea, demonstrations)       -0.095054   (eyewitness, helicopter)
# 77      (definition, experiment)        0.182097         (developer, death)
# 78            (cosmology, canon)        0.401291          (referent, lemon)
# 79           (portrait, listing)        0.107994                 (boa, ice)
# 80             (protest, suburb)        0.108032      (junior, application)
# 81              (timber, studio)       -0.005239          (amateur, result)
# 82        (status, compensation)        0.426271         (misses, findings)
# 83       (chronicle, convention)        0.110268     (husband, correlation)
# 84         (formation, doctrine)        0.159094     (shipmates, orchestra)
# 85              (policies, boat)       -0.204082          (senator, denial)
# 86             (vectors, moment)        0.144807         (pilot, existence)
# 87     (discrimination, factors)        0.352982          (pickers, heaven)
# 88            (panel, materials)        0.085945         (buyer, agreement)
# 89        (management, switches)        0.256898  (liberals, collaboration)
# 90              (money, records)        0.177110      (astronomer, country)
# 91                 (coal, needs)        0.038485    (intellectuals, jacket)
# 92       (developments, opinion)        0.319240    (grandfathers, defeats)
# 93                (names, hotel)       -0.039449     (merchants, greetings)
# 94            (octave, security)       -0.207031          (salesman, limit)
# 95                (thesis, head)        0.009819    (referee, illustration)
# 96               (stick, groups)       -0.017609     (stewardess, sequence)
# 97         (chambers, technique)       -0.053550   (intruders, hospitality)
# 98             (boards, privacy)        0.373797    (alcoholics, criterion)
# 99           (corruption, faith)        0.251447     (missionary, republic)
# 100           (pans, imperative)        0.125150              (nurse, hope)
# 101           (specimen, tracer)        0.274875       (cobbler, phonology)
# 102         (suffrage, arteries)       -0.127570        (builder, lingerie)
# 103          (engraving, canyon)        0.243519      (politician, concept)
# 104     (wakefulness, logarithm)        0.200884             (racist, game)
# 105           (outrages, social)        0.066802            (reporter, bar)
# 106                (class, coal)        0.038373           (student, press)
# 107        (contentment, malady)        0.418817          (employers, city)
# 108              (menu, charity)        0.017543     (celebrity, cigarette)
# 109             (meantime, club)        0.221057         (owner, tradition)
# 110         (appointment, moral)        0.254113           (humorist, risk)
# 111              (siren, radius)        0.310828           (liar, building)
# 112                (lips, equal)        0.080291   (nationals, handwriting)
# 113          (helicopter, death)       -0.068966     (millionaire, economy)
# 114                 (lemon, ice)        0.320127           (bishop, lounge)
# 115        (application, result)        0.166517            (mayor, doubts)
# 116      (findings, correlation)        0.277745         (artist, benefits)
# 117          (orchestra, denial)       -0.339395        (princess, margins)
# 118          (existence, heaven)        0.392595       (householder, music)
# 119   (agreement, collaboration)        0.315872         (gymnast, cartoon)
# 120            (country, jacket)       -0.094284          (customer, night)
# 121         (defeats, greetings)        0.005609            (pianist, cake)
# 122        (limit, illustration)        0.154180         (retailers, month)
# 123      (sequence, hospitality)       -0.127187        (assassins, income)
# 124        (criterion, republic)        0.062358            (giant, winter)
# 125            (hope, phonology)       -0.147273            (planner, foot)
# 126          (lingerie, concept)       -0.183202         (female, airplane)
# 127                  (game, bar)        0.163190           (thinker, niche)
# 128                (press, city)        0.054807        (controller, taint)
# 129       (cigarette, tradition)       -0.115003         (civilian, essays)
# 130             (risk, building)       -0.086207          (craftsman, town)
# 131       (handwriting, economy)       -0.003597       (travellers, nuclei)
# 132             (lounge, doubts)       -0.103825            (poets, access)
# 133          (benefits, margins)        0.196101          (analyst, honour)
# 134             (music, cartoon)        0.253553       (sardines, membrane)
# 135                (night, cake)        0.297786           (preacher, dust)
# 136              (month, income)        0.243430       (youths, milligrams)
# 137               (winter, foot)        0.210078        (planters, fashion)
# 138            (airplane, niche)        0.193664     (purist, explorations)
# 139              (taint, essays)        0.114440      (spectators, quality)
# 140               (town, nuclei)       -0.102117    (instructor, beginning)
# 141             (access, honour)       -0.094404     (champions, departure)
# 142             (membrane, dust)        0.601756             (police, tape)
# 143        (milligrams, fashion)       -0.145451    (selectors, cerebellum)
# 144      (explorations, quality)        0.111974    (graduate, cooperative)
# 145       (beginning, departure)        0.375800         (contender, plane)
# 146           (tape, cerebellum)        0.240027              (farmer, ear)
# 147         (cooperative, plane)       -0.063369     (descendant, finality)
# 148              (ear, finality)        0.176993           (dancers, quote)
# 149             (quote, arcades)        0.011649           (horse, arcades)
#
#      Simval_contrast
# 0           0.007539
# 1           0.081350
# 2          -0.005888
# 3           0.152362
# 4          -0.126815
# 5          -0.135816
# 6           0.136031
# 7          -0.072913
# 8           0.030814
# 9          -0.044760
# 10          0.254799
# 11          0.363557
# 12          0.657578
# 13          0.282995
# 14          0.014060
# 15          0.244506
# 16          0.128781
# 17          0.179345
# 18         -0.081156
# 19          0.157285
# 20          0.606047
# 21          0.120473
# 22         -0.034526
# 23          0.050138
# 24         -0.051865
# 25         -0.205206
# 26          0.006112
# 27         -0.120178
# 28          0.049451
# 29         -0.240633
# 30          0.288705
# 31          0.054857
# 32          0.224455
# 33         -0.225833
# 34          0.138406
# 35          0.196598
# 36          0.056916
# 37          0.034581
# 38         -0.036662
# 39          0.267201
# 40         -0.087898
# 41          0.229502
# 42          0.190971
# 43         -0.207774
# 44         -0.083194
# 45         -0.203489
# 46          0.201985
# 47         -0.099502
# 48          0.204247
# 49         -0.058113
# 50          0.481573
# 51          0.124441
# 52          0.164963
# 53          0.272061
# 54          0.124433
# 55          0.129290
# 56          0.275371
# 57          0.171279
# 58          0.276992
# 59          0.052898
# 60          0.365466
# 61         -0.083376
# 62          0.008038
# 63         -0.093933
# 64          0.481098
# 65          0.412845
# 66         -0.122099
# 67          0.082744
# 68          0.367191
# 69         -0.170966
# 70          0.235996
# 71         -0.113751
# 72          0.044220
# 73          0.017442
# 74          0.224995
# 75          0.000378
# 76         -0.004600
# 77         -0.197566
# 78          0.190238
# 79          0.257461
# 80         -0.178164
# 81         -0.040422
# 82         -0.125160
# 83          0.026893
# 84          0.085623
# 85          0.030532
# 86         -0.080668
# 87          0.254389
# 88          0.238901
# 89          0.126358
# 90         -0.218060
# 91         -0.138436
# 92          0.297841
# 93          0.178035
# 94         -0.120865
# 95          0.040986
# 96          0.056528
# 97          0.437522
# 98          0.174741
# 99          0.088802
# 100         0.211268
# 101         0.201073
# 102         0.361243
# 103        -0.142412
# 104        -0.078894
# 105         0.130717
# 106         0.188963
# 107         0.197684
# 108         0.229554
# 109        -0.097376
# 110         0.005485
# 111        -0.287226
# 112        -0.113511
# 113        -0.078690
# 114        -0.174905
# 115         0.037650
# 116        -0.163715
# 117        -0.167289
# 118         0.106272
# 119         0.223424
# 120         0.030769
# 121         0.337783
# 122        -0.042924
# 123        -0.178410
# 124         0.068162
# 125        -0.089221
# 126         0.018070
# 127         0.047057
# 128         0.138501
# 129        -0.268967
# 130         0.131550
# 131         0.054858
# 132        -0.235397
# 133         0.159458
# 134         0.101320
# 135        -0.152461
# 136         0.149112
# 137         0.109909
# 138         0.138597
# 139         0.208773
# 140         0.084929
# 141         0.063059
# 142         0.035531
# 143         0.260630
# 144         0.379130
# 145         0.049236
# 146         0.191714
# 147         0.283874
# 148         0.010214
# 149         0.184137

# %% [markdown]
# Now we export the dataframe to be able to use it for data analysis.

# %%
df_simval.to_csv('df_simval.csv', sep=',', header=False, index=True)
